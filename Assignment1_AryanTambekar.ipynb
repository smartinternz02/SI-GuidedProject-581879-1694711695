# %%
import pandas as pd
import numpy as np

# %% [markdown]
# TASK - 1

# %%
np.random.seed(42)

# %%
random_values=np.random.rand(10,5)

# %%
df=pd.DataFrame(random_values)

# %%
df
# Out:
#           0         1         2         3         4
# 0  0.374540  0.950714  0.731994  0.598658  0.156019
# 1  0.155995  0.058084  0.866176  0.601115  0.708073
# 2  0.020584  0.969910  0.832443  0.212339  0.181825
# 3  0.183405  0.304242  0.524756  0.431945  0.291229
# 4  0.611853  0.139494  0.292145  0.366362  0.456070
# 5  0.785176  0.199674  0.514234  0.592415  0.046450
# 6  0.607545  0.170524  0.065052  0.948886  0.965632
# 7  0.808397  0.304614  0.097672  0.684233  0.440152
# 8  0.122038  0.495177  0.034389  0.909320  0.258780
# 9  0.662522  0.311711  0.520068  0.546710  0.184854

# %% [markdown]
# TASK - 2

# %%
df.columns=['c1','c2','c3','c4','c5']

# %%
df
# Out:
#          c1        c2        c3        c4        c5
# 0  0.374540  0.950714  0.731994  0.598658  0.156019
# 1  0.155995  0.058084  0.866176  0.601115  0.708073
# 2  0.020584  0.969910  0.832443  0.212339  0.181825
# 3  0.183405  0.304242  0.524756  0.431945  0.291229
# 4  0.611853  0.139494  0.292145  0.366362  0.456070
# 5  0.785176  0.199674  0.514234  0.592415  0.046450
# 6  0.607545  0.170524  0.065052  0.948886  0.965632
# 7  0.808397  0.304614  0.097672  0.684233  0.440152
# 8  0.122038  0.495177  0.034389  0.909320  0.258780
# 9  0.662522  0.311711  0.520068  0.546710  0.184854

# %% [markdown]
# TASK - 3

# %%
df.describe()
# Out:
#               c1         c2         c3         c4         c5
# count  10.000000  10.000000  10.000000  10.000000  10.000000
# mean    0.433206   0.390414   0.447893   0.589198   0.368908
# std     0.296145   0.323152   0.313322   0.225915   0.282867
# min     0.020584   0.058084   0.034389   0.212339   0.046450
# 25%     0.162847   0.177812   0.146290   0.460636   0.182582
# 50%     0.491042   0.304428   0.517151   0.595537   0.275005
# 75%     0.649855   0.449310   0.680185   0.663454   0.452091
# max     0.808397   0.969910   0.866176   0.948886   0.965632

# %% [markdown]
# TASK - 4

# %%
df.isnull().any()
# Out:
# c1    False
# c2    False
# c3    False
# c4    False
# c5    False
# dtype: bool

# %% [markdown]
# TASK - 5

# %%
df.loc[:,'c2']
# Out:
# 0    0.950714
# 1    0.058084
# 2    0.969910
# 3    0.304242
# 4    0.139494
# 5    0.199674
# 6    0.170524
# 7    0.304614
# 8    0.495177
# 9    0.311711
# Name: c2, dtype: float64

# %%
df.iloc[:,df.columns.get_loc('c3')]
# Out:
# 0    0.731994
# 1    0.866176
# 2    0.832443
# 3    0.524756
# 4    0.292145
# 5    0.514234
# 6    0.065052
# 7    0.097672
# 8    0.034389
# 9    0.520068
# Name: c3, dtype: float64
